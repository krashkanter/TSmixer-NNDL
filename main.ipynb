# %%
import pandas as pd

# %%
data = pd.read_csv("datasets/559_train.csv")
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#              index_new  glucose  gsr  hr   st  basal  bolus  bolus_dur  \
# 0  2021-12-07 00:00:00       -1 -1.0  -1 -1.0   0.65   -1.0         -1
# 1  2021-12-07 01:05:00       -1 -1.0  -1 -1.0   0.65    1.6          0
# 2  2021-12-07 01:15:00      101 -1.0  -1 -1.0   0.65   -1.0         -1
# 3  2021-12-07 01:20:00       98 -1.0  -1 -1.0   0.65   -1.0         -1
# 4  2021-12-07 01:25:00      104 -1.0  -1 -1.0   0.65   -1.0         -1
#
#              bolus_end  temp_basal  ... work_dur  work_end exercise_intensity  \
# 0                   -1        -1.0  ...       -1        -1                 -1
# 1  2021-12-07 01:05:00        -1.0  ...       -1        -1                 -1
# 2                   -1        -1.0  ...       -1        -1                 -1
# 3                   -1        -1.0  ...       -1        -1                 -1
# 4                   -1        -1.0  ...       -1        -1                 -1
#
#    exer_dur                index temp_bolus  temp_sleep  temp_work  \
# ...
